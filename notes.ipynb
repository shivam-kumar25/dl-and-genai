# %% [markdown]
# ` Mechine Learning is the field of study that gives computers the ability to learn without being explicitly programmed. `

# %% [markdown]
# ### Traditional Machine Learning vs Deep Learning
#
#
#
# ![limitations-of-traditional-ml.png](attachment:limitations-of-traditional-ml.png)
#
#
# ![traditional-ml-vs-deep-learning.png](attachment:traditional-ml-vs-deep-learning.png)
#
# ![ml-vs-dl.png](attachment:ml-vs-dl.png)
